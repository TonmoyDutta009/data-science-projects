# %%
import gdown

# %%
# !gdown 1-pOuGRd8zuAUKBll-1xkr7_867NwoWHg
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1-pOuGRd8zuAUKBll-1xkr7_867NwoWHg
# To: /Users/tonmoydutta/PycharmProjects/JupyterProject/models/mobilesales.xlsx
# 100%|██████████████████████████████████████| 13.7k/13.7k [00:00<00:00, 19.4MB/s]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (20,6)

# %%
mobile_sales = pd.read_excel('/Users/tonmoydutta/PycharmProjects/JupyterProject/models/mobilesales.xlsx')
mobile_sales.head()
# Out:
#         DATE   Sales
# 0 2001-01-01  6519.0
# 1 2001-02-01  6654.0
# 2 2001-03-01  7332.0
# 3 2001-04-01  7332.0
# 4 2001-05-01  8240.0

# %%
mobile_sales.dtypes
# Out:
# DATE     datetime64[ns]
# Sales           float64
# dtype: object

# %%
mobile_sales.Sales.describe()
# Out:
# count      198.000000
# mean     10842.757576
# std       2605.006293
# min        108.000000
# 25%       8856.000000
# 50%      10745.000000
# 75%      12399.750000
# max      23740.000000
# Name: Sales, dtype: float64

# %%
mobile_sales.DATE.describe()
# Out:
# count                              217
# mean     2009-12-31 04:25:26.267281152
# min                2001-01-01 00:00:00
# 25%                2005-07-01 00:00:00
# 50%                2010-01-01 00:00:00
# 75%                2014-07-01 00:00:00
# max                2019-01-01 00:00:00
# Name: DATE, dtype: object

# %%
18*12 + 1
# Out:
# 217

# %%
mobile_sales.index
# Out:
# RangeIndex(start=0, stop=217, step=1)
